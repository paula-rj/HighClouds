# %% [markdown]
# # Intro

# %%
import numpy as np

import  matplotlib.dates as mdates
import matplotlib.patches as patches
import matplotlib.pyplot as plt

import cartopy as cart
import cartopy.crs as ccrs
import cartopy.feature as cfeature

import pandas as pd

import xarray as xa

# %%
path_pics = "../pictures"

# %%
all0205 = xa.open_dataset("../daa/allPacific/CERES_FluxByCldTyp-MON_Terra-Aqua-MODIS_Ed4.1_Subset_200208-200508.nc", engine='netcdf4')
all0508 = xa.open_dataset("../daa/allPacific/CERES_FluxByCldTyp-MON_Terra-Aqua-MODIS_Ed4.1_Subset_200509-200809.nc", engine='netcdf4')
all0811 = xa.open_dataset("../daa/allPacific/CERES_FluxByCldTyp-MON_Terra-Aqua-MODIS_Ed4.1_Subset_200810-201110.nc", engine='netcdf4')
all1114 = xa.open_dataset("../daa/allPacific/CERES_FluxByCldTyp-MON_Terra-Aqua-MODIS_Ed4.1_Subset_201111-201411.nc", engine='netcdf4')
all1417 = xa.open_dataset("../daa/allPacific/CERES_FluxByCldTyp-MON_Terra-Aqua-MODIS_Ed4.1_Subset_201412-201712.nc", engine='netcdf4')
all1821 = xa.open_dataset("../daa/allPacific/CERES_FluxByCldTyp-MON_Terra-Aqua-MODIS_Ed4.1_Subset_201801-202101.nc", engine='netcdf4')
all2123 = xa.open_dataset("../daa/allPacific/CERES_FluxByCldTyp-MON_Terra-Aqua-MODIS_Ed4.1_Subset_202102-202302.nc", engine='netcdf4')

# %%
var = "cldtau"
alltau = xa.concat( [all0205[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all0508[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all0811[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all1114[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all1417[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all1821[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all2123[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],], 
               dim='time')

# %%
var = "cldtemp"
alltemp = xa.concat( [all0205[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all0508[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all0811[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all1114[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all1417[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all1821[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],
                 all2123[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon"]],], 
               dim='time')

# %%
var = "toa_lw"
alllw = xa.concat( [all0205[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_lw_clr_mon"]],
                    all0508[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_lw_clr_mon"]],
                    all0811[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_lw_clr_mon"]],
                    all1114[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_lw_clr_mon"]],
                    all1417[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_lw_clr_mon"]],
                    all1821[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_lw_clr_mon"]],
                    all2123[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_lw_clr_mon"]],], 
               dim='time')

# %%
var = "toa_sw"
allsw = xa.concat( [all0205[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_sw_clr_mon"]],
                    all0508[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_sw_clr_mon"]],
                    all0811[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_sw_clr_mon"]],
                    all1114[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_sw_clr_mon"]],
                    all1417[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_sw_clr_mon"]],
                    all1821[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_sw_clr_mon"]],
                    all2123[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", "toa_sw_clr_mon"]],], 
               dim='time')

# %%
var = "iwp"
iwp_all= xa.concat( [all0205[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all0508[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all0811[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all1114[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all1417[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all1821[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all2123[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],], 
               dim='time')

# %%
var = "cldicerad"
iwp_all= xa.concat( [all0205[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all0508[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all0811[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all1114[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all1417[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all1821[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],
                    all2123[["cldarea_cldtyp_mon", f"{var}_cldtyp_mon", ]],], 
               dim='time')

# %%
sst = xa.open_dataset("../daa/sst_mon_mean.nc", engine='netcdf4')

# %%
itcz = slice(5,15)
trop = slice(-30,30)
wp = slice(120,160)
cp = slice(160,200)
ep = slice(210,260)
newlat = slice(-0.5, 20.5)
ocean = slice(110,270)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
sst_itcz = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'), lat=slice(20.5,-0.5), lon=slice(120.5,269.5) ).mean(['lat', 'lon'])
sst_wp = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'), lat=slice(20.5,-0.5), lon=wp ).mean(['lat', 'lon'])
sst_ep = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'), lat=slice(20.5,-0.5), lon=ep ).mean(['lat', 'lon'])
temp_itcz = alltemp.cldtemp_cldtyp_mon.sel(lat=newlat, press=[4,5,6]).mean(['opt','press'])
area_itcz = alltemp.cldarea_cldtyp_mon.sel(lat=newlat, press=[4,5,6]).sum(['opt','press'])
odtropics = alltau.cldtau_cldtyp_mon.sel(press=[6,5,4], lat=slice(-30,30))
area_tropics = alltau.cldarea_cldtyp_mon.sel(press=[6,5,4], lat=slice(-30,30))
odweight = odtropics.weighted(area_tropics).mean(['press', 'opt'])

# %%
def netCRE(lw_flxds, sw_flxds, by_frac=False):
    """Calculates the net CRE given any FLx dataset
    
    Parameters
    ----------
    flxds: netcdf Dataset
        A flx dataset
        
    Returns
    -------
    net_cre: netcdf Dataset
        The Net CRE

    Notes
    -----
    Do't need to select cloud area area here because you can select 
    in the whole dataset, which includes cloud area. 
    """

    lw_cre = lw_flxds.toa_lw_clr_mon - lw_flxds.toa_lw_cldtyp_mon
    sw_cre = sw_flxds.toa_sw_clr_mon - sw_flxds.toa_sw_cldtyp_mon
    net_cre = lw_cre + sw_cre

    if by_frac:
        net_cre = net_cre * lw_flxds.cldarea_cldtyp_mon*0.01 
  
    return net_cre


cre_times = netCRE(alllw.sel(lat=trop, lon=ocean), allsw.sel(lat=trop, lon=ocean), by_frac=True)
cre_not_times = netCRE(alllw.sel(lat=trop), allsw.sel(lat=trop), by_frac=False)

# %%
crelw = alllw.assign(cre_lw_cldtyp_mon = alllw.toa_lw_clr_mon - alllw.toa_lw_cldtyp_mon)
cresw = allsw.assign(cre_sw_cldtyp_mon = allsw.toa_sw_clr_mon - allsw.toa_sw_cldtyp_mon)

# %% [markdown]
# # Bins plots

# %%
def cldtype_plots(dataset, var, contour=False, times_area=True, *args):
    """Plots datasets by cloud type i.e. CTP vs COD.
    dataset: xarray.Dataset    
        The dataset. MUst include cld_area together with the variable to plot.
    var: str
        The variable to plot. Just for the plot title.
    contour: bool
        Whether you want a contour plot. Optional contour args available.
        Default = False
    times_area: bool
        If true, times the dataset by cld_area dataset in the same domain.
        Default = True
    
    Returns
    -------
    Just the plot
    """
    # Turns around the plot, otherwise the pressure is in the x-axis
    if times_area: 
        mean_ds = dataset[f'{var}_cldtyp_mon'] * dataset.cldarea_cldtyp_mon *0.01
    else:
        mean_ds = dataset
        
    mean_ds = mean_ds.mean(['lat', 'lon', 'time']).transpose() 
    
    if contour:
        mean_ds.plot.contourf(extend="max", *args) 
    else:
        mean_ds.plot()
    
    # The tick labels for the axis are in the dataset comments 
    plt.yticks(np.arange(-0.5,7.5,1), [x.split(';')[0] for x in mean_ds.press.comment.split('-')])
    plt.xticks(np.arange(-0.5,6.5,1), [x.split(';')[0] for x in mean_ds.opt.comment.split('-')])
    tmin = pd.to_datetime(str(dataset.time.min().values)).strftime('%m-%Y')
    tmax = pd.to_datetime(str(dataset.time.max().values)).strftime('%m-%Y')
    plt.title(f'{tmin} to {tmax}, lat=[{dataset.lat.min().data.item()}, {dataset.lat.max().data.item()}],\
 lon=[{dataset.lon.min().data.item()} {dataset.lon.max().data.item()}]')
    plt.suptitle(f'Cloud {var}')

# %%
cldtype_plots(alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=ocean), 'area', times_area=False)

# %%
cldtype_plots(alltau.sel(lat=newlat, lon=ocean), 'cldtau', times_area=True)

# %%
cldtype_plots(cre_not_times.sel(lat=itcz), 'K not timed', times_area=False)

# %%
#Net CRE times cloud area 
cldtype_plots(cre_times.sel(lat=newlat, lon=ocean), 'ITCZ Net CRE', times_area=False)

# %%
crelw.cre_lw_cldtyp_mon.sel(lat=newlat, lon=ocean).mean(['lat', 'lon', 'time']).transpose().max()
# Out:
# <xarray.DataArray 'cre_lw_cldtyp_mon' ()>
# array(170.27827, dtype=float32)

# %%
def k_plot(ds, lat, lon, cmap):
    data = ds.sel(lat=lat, lon=lon).mean(['lat', 'lon', 'time']).transpose()
    mi = data.min()
    ma = data.max()
    data.plot(cmap=cmap, vmin=mi, vmax=ma, cbar_kwargs={'label': "Wm-2", 'extend': 'neither'})

# %%
k_plot(crelw.cre_lw_cldtyp_mon, newlat, ocean, "Reds")
plt.title("ITCZ-mean LW kernel")
# Out:
# Text(0.5, 1.0, 'ITCZ-mean LW kernel')

# %%
k_plot(cresw.cre_sw_cldtyp_mon, newlat, ocean, "Blues_r")
plt.title("ITCZ-mean SW kernel")
# Out:
# Text(0.5, 1.0, 'ITCZ-mean SW kernel')

# %%
k_plot((crelw.cre_lw_cldtyp_mon + cresw.cre_sw_cldtyp_mon), newlat, ocean, "RdBu_r")
plt.title("ITCZ-mean Net kernel")
plt.savefig("k_net.png")

# %%
lwK = crelw.cre_lw_cldtyp_mon.sel(lat=newlat, lon=ocean).mean(['lat', 'lon', 'time']).transpose()
swK = cresw.cre_sw_cldtyp_mon.sel(lat=newlat, lon=ocean).mean(['lat', 'lon', 'time']).transpose()
netK = lwK + swK 

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,4))

#fig.suptitle('Horizontally stacked subplots')
lwK.plot(cmap="Reds", vmin=0, vmax=160, cbar_kwargs={'label': "Wm-2", 'extend': 'neither'}, ax=ax1)
ax1.set_title("a) ITCZ-mean LW kernel")
swK.plot(cmap="Blues_r", vmin=-250, vmax=0, cbar_kwargs={'label': "Wm-2", 'extend': 'neither'}, ax=ax2)
ax2.set_title("b) ITCZ-mean SW kernel")
netK.plot(cmap="RdBu_r", vmin=-160, vmax=160, cbar_kwargs={'label': "Wm-2", 'extend': 'neither'}, ax=ax3)
ax3.set_title("c) ITCZ-mean net kernel")
plt.savefig("kernels.png")

# %%
#LW CRE times cloud area 
cldtype_plots(crelw.sel(lat=newlat, lon=ocean), 'cre_lw', times_area=True)

# %%
#SW CRE times cloud area 
cldtype_plots(cresw.sel(lat=newlat, lon=ocean), 'cre_sw', times_area=True)

# %%
cldtype_plots(iwp_all.sel(lat=itcz, lon=ocean), 'iwp', times_area=True)

# %% [markdown]
# # Maps

# %%
usemap_proj = ccrs.PlateCarree(central_longitude=180)

# %%
area = alltau.cldarea_cldtyp_mon.sel(press=[6,5,4], lat=slice(-30,30), lon=ocean).sum([ 'press', 'opt']).mean(['time',])

plt.figure(figsize=(10,10))
ax1 = plt.axes(projection=usemap_proj)

plot = area.plot(extend='both',transform = ccrs.PlateCarree(), add_colorbar=False, cmap='Blues')#, extend='both',transform=cart.crs.PlateCarree())

ax1.coastlines(resolution='50m') #transparent
#ax1.set_extent([data.lon.min().data.item(), data.lon.max().data.item(), data.lat.min().data.item(), data.lat.max().data.item()])
gl = ax1.gridlines(draw_labels=True, linewidth=0.5, alpha=0.4, color='k', linestyle='--')
ax1.add_patch(patches.Rectangle(xy=[120, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[160, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[210, 0], width=50, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
plt.colorbar(plot,fraction=0.019, pad=0.04)
plt.title('High clouds area')
#plt.savefig("area_map.svg", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10,10))
ax1 = plt.axes(projection=usemap_proj)

plot = odweight.mean(['time']).plot(cmap='OrRd', extend='both',transform = ccrs.PlateCarree(), add_colorbar=False)#, extend='both',transform=cart.crs.PlateCarree())

ax1.coastlines(resolution='50m') #transparent
#ax1.set_extent([data.lon.min().data.item(), data.lon.max().data.item(), data.lat.min().data.item(), data.lat.max().data.item()])
gl = ax1.gridlines(draw_labels=True, linewidth=0.5, alpha=0.4, color='k', linestyle='--')
ax1.add_patch(patches.Rectangle(xy=[120, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[160, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[210, 0], width=50, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
plt.colorbar(plot,fraction=0.019, pad=0.04)
plt.title('Optical depth')
plt.show()
plt.savefig("OD_map.png")

# %%
od_clim = odweight.groupby("time.month").mean("time")

# %%
for i in np.arange(1,13):
    ax = plt.axes(projection=usemap_proj)
    plot = od_clim.sel(month=i).plot(cmap='OrRd', extend='both',transform = ccrs.PlateCarree(), add_colorbar=False, vmin=0, vmax=40)#, extend='both',transform=cart.crs.PlateCarree())
    ax.coastlines(resolution='50m') #transparent
    gl = ax.gridlines(draw_labels=True, linewidth=0.5, alpha=0.4, color='k', linestyle='--')
    ax.add_patch(patches.Rectangle(xy=[120, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
    ax.add_patch(patches.Rectangle(xy=[160, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
    ax.add_patch(patches.Rectangle(xy=[210, 0], width=50, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
    plt.colorbar(plot,fraction=0.019, pad=0.04)
    plt.title(f'{months[i-1]} ')
    plt.savefig(f"OD_{months[i-1]}.png", bbox_inches="tight")
    plt.show()

# %%
lw_cre = alllw.sel(lat=slice(-30.5,30.5)).toa_lw_clr_mon - alllw.sel(lat=slice(-30.5,30.5)).toa_lw_cldtyp_mon
sw_cre = allsw.sel(lat=slice(-30.5,30.5)).toa_sw_clr_mon - allsw.sel(lat=slice(-30.5,30.5)).toa_sw_cldtyp_mon
net_cre = lw_cre + sw_cre

net_cre = net_cre * alllw.sel(lat=slice(-30.5,30.5)).cldarea_cldtyp_mon*0.01

# %%
data = net_cre.sel(press=[6,5,4]).sum(['press']).mean(['opt','time', ])

plt.figure(figsize=(10,10))
ax1 = plt.axes(projection=usemap_proj)

plot = data.plot(extend='both',transform = ccrs.PlateCarree(), add_colorbar=False)#, extend='both',transform=cart.crs.PlateCarree())

ax1.coastlines(resolution='50m') #transparent
#ax1.set_extent([data.lon.min().data.item(), data.lon.max().data.item(), data.lat.min().data.item(), data.lat.max().data.item()])
gl = ax1.gridlines(draw_labels=True, linewidth=0.5, alpha=0.4, color='k', linestyle='--')
ax1.add_patch(patches.Rectangle(xy=[120, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[160, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[210, 0], width=50, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
plt.colorbar(plot,fraction=0.019, pad=0.04, label= "$Wm^{-2}$")
plt.title(f'Net CRE')
plt.savefig("netCRE_map.png", bbox_inches="tight")
plt.show()

# %%
area_clim = area_tropics.sum(["press","opt"]).groupby("time.month").mean("time")

months=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

for i in np.arange(1,13):
    ax = plt.axes(projection=usemap_proj)
    plot = area_clim.sel(month=i).plot(extend='both',transform = ccrs.PlateCarree(), add_colorbar=False, vmin=0, vmax=80)#, extend='both',transform=cart.crs.PlateCarree())
    ax.coastlines(resolution='50m') #transparent
    gl = ax.gridlines(draw_labels=True, linewidth=0.5, alpha=0.4, color='k', linestyle='--')
    ax.add_patch(patches.Rectangle(xy=[120, 0], width=40, height=20, facecolor='none', edgecolor='w', transform=ccrs.PlateCarree()))
    ax.add_patch(patches.Rectangle(xy=[160, 0], width=40, height=20, facecolor='none', edgecolor='w', transform=ccrs.PlateCarree()))
    ax.add_patch(patches.Rectangle(xy=[210, 0], width=50, height=20, facecolor='none', edgecolor='w', transform=ccrs.PlateCarree()))
    plt.colorbar(plot,fraction=0.019, pad=0.04)
    plt.title(f'{months[i-1]} ')
    plt.savefig(f"CF_{months[i-1]}.png", bbox_inches="tight")
    plt.show()

# %%
iwp = iwp_all.iwp_cldtyp_mon.sel(press=[4,5,6]).weighted(iwp_all.cldarea_cldtyp_mon.sel(press=[4,5,6])).mean(["opt","press",])
iwp.mean(["time"]).plot(cmap="Blues")

# %%
plt.scatter(iwp.sel(lat=newlat, lon=ocean).mean(["lat", "lon"]), net_itcz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20723/742989795.py in <module>
# ----> 1 plt.scatter(iwp.sel(lat=newlat, lon=ocean).mean(["lat", "lon"]), net_itcz)
#
# NameError: name 'net_itcz' is not defined

# %% [markdown]
# # Climatology

# %%
# High clouds net CRE times area in ITCZ
fig, ax1 = plt.subplots(figsize=(10,6))
cre_times.sel( lat=newlat, lon=ocean, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).plot(linewidth=0.6, ax=ax1) 
plt.axhline(y=2.0, color='r', linestyle='-')
plt.axhline(y=-2.0, color='r', linestyle='-')
plt.title("High clouds Net CRE in ITCZ")
plt.ylabel("net CRE (Wm-2)")
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=6)) 
ax1.grid(visible=True, axis='x')

# %%
net_itcz = cre_times.sel(lat=newlat , lon=ocean, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon'])
net_month_clim = net_itcz.groupby("time.month").mean("time")
net_anom = net_itcz.groupby("time.month") - net_month_clim

# %%
# Monthly climatology high clouds net CRE times area in ITCZ
fig, ((ax1, ax2), (ax3, ax4))  = plt.subplots(2,2, figsize=(10,8))

lw_itcz.mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax1) 
plt.ylabel("LW CRE (Wm-2)")
ax1.grid(visible=True, axis='both')
ax1.set_ylabel("LW CRE (Wm-2)")
ax1.set_xticks(np.arange(1,13,1))
ax1.set_xticklabels(months)
ax1.set_title("a)", loc="left")

sw_itcz.mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax2) 
plt.ylabel("SW CRE (Wm-2)")
ax2.grid(visible=True, axis='both')
ax2.set_ylabel("SW CRE (Wm-2)")
ax2.set_xticks(np.arange(1,13,1))
ax2.set_xticklabels(months)
ax2.set_title("b)", loc="left")

alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=ocean, press=[4,5,6]).sum(["press", "opt"]).mean(['lat', 'lon']).groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax3) 
plt.ylabel("Cloud fraction (%)")
ax3.grid(visible=True, axis='both')
ax3.set_ylabel("cloud fraction (%)")
ax3.set_xticks(np.arange(1,13,1))
ax3.set_xticklabels(months)
ax3.set_title("c)", loc="left")

ncre_times = cre_times.sel(lat=newlat, lon=ocean, press=[4,5,6,])
net_itcz.groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax4) 
ax4.set_ylabel("net CRE (Wm-2)")
ax4.grid(visible=True, axis='both')
ax4.set_xticks(np.arange(1,13,1))
ax4.set_xticklabels(months)
ax4.set_title("d)", loc="left")

#plt.savefig("clims-subpts.png")
#tmin = pd.to_datetime(str(net_itcz.time.min().values)).strftime('%m-%Y')
#tmax = pd.to_datetime(str(net_itcz.time.max().values)).strftime('%m-%Y')
#plt.title(f'{tmin} to {tmax}, lat=[{ncre_times.lat.min().data.item()}, {ncre_times.lat.max().data.item()}],\
#lon=[{ncre_times.lon.min().data.item()} {ncre_times.lon.max().data.item()}]')
#ax1.set_title("High clouds net CRE monthly mean")

# %%
# Monthly climatology High clouds od weighted area in ITCZ
fig, ax1 = plt.subplots()
odweight.sel(lat=newlat, lon=ep).mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax1) 
plt.ylabel("Optical Depth ")
ax1.grid(visible=True, axis='both')
plt.xticks(np.arange(1,13,1), months)
tmin = pd.to_datetime(str(net_itcz.time.min().values)).strftime('%m-%Y')
tmax = pd.to_datetime(str(net_itcz.time.max().values)).strftime('%m-%Y')
plt.title(f'{tmin} to {tmax}, lat=[{odweight.sel(lat=newlat, lon=ep).lat.min().data.item()}, {odweight.sel(lat=newlat, lon=ep).lat.max().data.item()}],\
lon=[{odweight.sel(lat=newlat, lon=ep).lon.min().data.item()} {odweight.sel(lat=newlat, lon=ep).lon.max().data.item()}]')
plt.suptitle("High clouds OD weighted by cloud area")
plt.savefig('pictures/ep-od-month-clim.png')

# %%
def plot_monthly_clim(varname, ds, lat, lon):
    """Calculates ds monthly climatology and plots it"""
    fig, ax1 = plt.subplots()
    ds.sel(lat=lat, lon=lon, press=[4,5,6]).sum(["press", "opt"]).mean(['lat', 'lon']).groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax1) 
    ax1.grid(visible=True, axis='both')
    plt.xticks(np.arange(1,13,1), months)
    plt.title(f'{tmin} to {tmax}, lat=[{ds.sel(lat=lat, lon=lon).lat.min().data.item()}, {ds.sel(lat=lat, lon=lon).lat.max().data.item()}],\
    lon=[{ds.sel(lat=lat, lon=lon).lon.min().data.item()} {ds.sel(lat=lat, lon=lon).lon.max().data.item()}]')
    plt.ylabel(varname)
    plt.suptitle(f"High clouds {varname} monthly mean")
   # plt.savefig('pictures/ep-od-monthclim.png')

# %%
plot_monthly_clim('area', alltau.cldarea_cldtyp_mon, newlat, wp)

# %%
lw_cre = crelw.toa_lw_clr_mon - crelw.toa_lw_cldtyp_mon
lw_flxds = lw_cre * crelw.cldarea_cldtyp_mon*0.01 
lw_itcz = lw_flxds.sel(lat=newlat, lon=ocean, press=[4,5,6,]).sum(["press", "opt"])

# %%
# Monthly climatology High clouds net CRE times area in ITCZ
fig, ax1 = plt.subplots()
lw_itcz.mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax1) 
plt.ylabel("LW CRE (Wm-2)")
ax1.grid(visible=True, axis='both')
plt.xticks(np.arange(1,13,1), months)
plt.title(f'{tmin} to {tmax}, lat=[{lw_itcz.lat.min().data.item()}, {lw_itcz.lat.max().data.item()}],\
lon=[{lw_itcz.lon.min().data.item()} {lw_itcz.lon.max().data.item()}]')
plt.suptitle("High clouds LW CRE x cloud area monthly mean")

# %%
sw_cre = cresw.toa_sw_clr_mon - cresw.toa_sw_cldtyp_mon
sw_flxds = sw_cre * cresw.cldarea_cldtyp_mon*0.01 
sw_itcz = sw_flxds.sel(lat=newlat, lon=ocean, press=[4,5,6,]).sum(["press", "opt"])

# %%
fig, ax1 = plt.subplots()
sw_itcz.mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax1) 
plt.ylabel("SW CRE (Wm-2)")
ax1.grid(visible=True, axis='both')
plt.xticks(np.arange(1,13,1), months)
plt.title(f'{tmin} to {tmax}, lat=[{ncre_times.lat.min().data.item()}, {ncre_times.lat.max().data.item()}],\
lon=[{ncre_times.lon.min().data.item()} {ncre_times.lon.max().data.item()}]')
plt.suptitle("High clouds SW CRE x cloud area monthly mean")

# %%
fig, ax1  = plt.subplots()

lw_flxds.sel(lat=newlat, lon=ep, press=[4,5,6,]).sum(["press", "opt"]).mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, color='r',ax=ax1) 

ax1.grid(visible=True, axis='both')

ax1.set_xticks(np.arange(1,13,1))
ax1.set_xticklabels(months)
ax1.set_title("EP CRE", loc="left")

sw_flxds.sel(lat=newlat, lon=ep, press=[4,5,6,]).sum(["press", "opt"]).mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, color='b',ax=ax1) 

ncre_times = cre_times.sel(lat=newlat, lon=ep, press=[4,5,6,])
net_itcz.groupby("time.month").mean("time").plot(linewidth=0.6, color='g', ax=ax1) 
ax1.set_ylabel("CRE (Wm-2)")
plt.savefig("pictures/ep-month-cre.png")

# %%
fig, ax1  = plt.subplots()

lw_flxds.sel(lat=newlat, lon=wp, press=[4,5,6,]).sum(["press", "opt"]).mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, color='r', ax=ax1) 

ax1.grid(visible=True, axis='both')

ax1.set_xticks(np.arange(1,13,1))
ax1.set_xticklabels(months)
ax1.set_title("WP CRE", loc="left")

sw_flxds.sel(lat=newlat, lon=wp, press=[4,5,6,]).sum(["press", "opt"]).mean(["lat", "lon"]).groupby("time.month").mean("time").plot(linewidth=0.6, color='b', ax=ax1) 

ncre_times = cre_times.sel(lat=newlat, lon=wp, press=[4,5,6,])
net_itcz.groupby("time.month").mean("time").plot(linewidth=0.6, color='g',ax=ax1) 
ax1.set_ylabel("CRE (Wm-2)")
#plt.legend(loc="upper right")
plt.savefig("pictures/wp-month-cre.png")

# %% [markdown]
# # Anomalies

# %%
#ESTO VER ! ANTES ERA net_cre > anom_terciles
anom_terciles = net_anom.quantile(q=[0.33,0.66], dim="time")
anomUpperT = xa.where(net_anom > anom_terciles[1], 1, np.nan) # upper tercile
anomLowerT = xa.where(net_anom < anom_terciles[0], 1, np.nan)  # lower tercile
anom_terciles.data[:]

# %%
net_itcz.mean()

# %%
pares = []
for i in np.arange(0,len(net_anom.time.data)*2):
    if i%2==0:
        pares.append(i)
print(pares)

start_date = pd.to_datetime('2002-08-15T00:00:00.000000000')
dates = pd.date_range(start_date, periods=len(net_anom.time.data)*2, freq='SM')
dates = [dates[i] for i in pares]
dates

# %%
# Monthly climatology High clouds net CRE times area in ITCZ
fig, ax1 = plt.subplots(figsize=(15,9))
plt.plot(net_anom)
plt.title("High clouds Net CRE - Monthly anomaly")
plt.xlim(-1,248)
plt.ylabel("net CRE (Wm-2)")
plt.axhline(y=anom_terciles[0], color='r', linestyle='-')
plt.axhline(y=anom_terciles[1], color='r', linestyle='-')
#plt.axhline(y=p90[0], color='g', linestyle='-')
#plt.axhline(y=p90[1], color='g', linestyle='-')
ax1.grid(visible=True, axis='x')

# Convert integer months to actual dates
date_labels = [date.strftime('%Y-%d-%m') for date in dates]
tick_locations = np.arange(0, len(net_anom.time.data), 6)  # Show ticks every 12 months
plt.xticks(tick_locations, date_labels[::6], rotation=45)
plt.savefig("netCRE_timesseries.png")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,4))

xticks = np.arange(1,13,1)
ax1.stairs(monthsUp.data, np.arange(0.5,13.5,1))
ax1.set_title("a) in upper tercile")
ax1.set_xticks(xticks)
ax1.set_xticklabels(months)
ax1.set_yticks(np.arange(0,12))
ax1.set_ylabel("Number of events")

ax2.stairs(monthsLow.data, np.arange(0.5,13.5,1))
ax2.set_title("b) in lower tercile")
ax2.set_xticks(xticks)
ax2.set_xticklabels(months)
ax2.set_yticks(np.arange(0,12))

plt.savefig("hists.png")

# %%
monthsLow.data.mean()

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

monthsUp = anomUpperT.groupby("time.month").sum()
print(monthsUp.data)

plt.stairs(monthsUp.data, np.arange(0.5,13.5,1))

plt.xticks(np.arange(1,13,1), months)
plt.title('Number of events in netCRE upper tercile per month')

# %%
monthsLow = anomLowerT.groupby("time.month").sum()
print(monthsLow.data)

plt.stairs(monthsLow.data, np.arange(0.5,13.5,1))
plt.xticks(np.arange(1,13,1), months)
plt.title('Number of events in netCRE lower tercile per month')

# %%
xa.corr(sst_anom_latlon.sel(lat=slice(20.5,-0.5), lon=ocean).mean(['lat','lon']), net_anom)

# %%
# Monthly climatology High clouds net CRE times area in ITCZ
fig, ax1 = plt.subplots(figsize=(15,9))
sst_month_clim = sst_itcz.groupby("time.month").mean("time")
sst_anom = sst_itcz.groupby("time.month") - sst_month_clim
plt.plot(sst_anom)
#plt.title("SST monthly annomaly in ITCZ")
plt.xlim(-1,248)
plt.ylabel("Temperature ($^\circ C$)")
#ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=6)) 
ax1.grid(visible=True, axis='x')
date_labels = [date.strftime('%Y-%d-%m') for date in dates]
tick_locations = np.arange(0, len(net_anom.time.data), 6)  # Show ticks every 12 months
plt.xticks(tick_locations, date_labels[::6], rotation=45)
plt.savefig("ssttimeseries.png")

# %%
#ITCZ ANOM net CRE vs SSTs
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots(figsize=(10,6))

color = 'tab:red'
p1, = net_anom.plot(linewidth=0.6, ax=ax1, color=color,) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst_anom.plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("High clouds netCRE and SST monthly anomalies - Lat=[5,15], Lon=[120,280]")
ax1.set_ylabel("Net CRE (Wm-2)")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=1))
ax1.xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
ax1.grid(visible=True, axis='x')

plt.show()

# %%
rolling = net_anom.rolling(time=3)
with_dim = rolling.construct('window_dim')

# %%
rolling2 = sst_anom.rolling(time=3)
with_dim2 = rolling.construct('window_dim')

# %%
roll_corr = xa.corr(with_dim, with_dim2, dim='window_dim')

# %%
roll_corr.plot.scatter()

# %%
# Monthly climatology High clouds net CRE times area in ITCZ
fig, ax1 = plt.subplots(figsize=(10,6))
od_month_clim = odweight.sel(lat=slice(5,15)).mean(['lat', 'lon']).groupby("time.month").mean("time")
od_anom = odweight.sel(lat=slice(5,15)).mean(['lat', 'lon']).groupby("time.month") - od_month_clim
plt.plot(od_anom)
plt.title("Optical Depth weighted by cloud area monthly annomaly in ITCZ")
plt.xlim(-1,248)
plt.ylabel("OD")
#ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=6)) 
ax1.grid(visible=True, axis='x')

# %%
# Monthly climatology High clouds net CRE times area in ITCZ
fig, ax1 = plt.subplots(figsize=(10,6))
temp_month_clim = temp_itcz.mean(['lat', 'lon']).groupby("time.month").mean("time")
temp_anom = temp_itcz.mean(['lat', 'lon']).groupby("time.month") - temp_month_clim
temp_anom.plot()
plt.title("Cloud Eff Temp monthly annomaly in ITCZ")
plt.ylabel("CET (C)")
ax1.xaxis.set_major_locator(mdates.YearLocator(base=1)) 
ax1.grid(visible=True, axis='x')

# %%
# Monthly climatology High clouds net CRE times area in ITCZ
fig, ax1 = plt.subplots(figsize=(10,6))
area_month_clim = area_itcz.mean(['lat', 'lon']).groupby("time.month").mean("time")
area_anom = area_itcz.mean(['lat', 'lon']).groupby("time.month") - area_month_clim
area_anom.plot()
plt.title("Cloud area monthly anomaly in ITCZ")
plt.ylabel("Cloud Area (%)")
ax1.xaxis.set_major_locator(mdates.YearLocator(base=1)) 
ax1.grid(visible=True, axis='x')

# %% [markdown]
# # Terciles

# %% [markdown]
# ## ITCZ

# %%
net_itcz = cre_times.sel(lat=newlat , lon=ocean, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon'])
anom_terciles = net_anom.quantile(q=[0.33,0.66], dim="time")
anomUpperT = xa.where(net_anom > anom_terciles[1], 1, np.nan) # upper tercile
anomLowerT = xa.where(net_anom < anom_terciles[0], 1, np.nan)  # lower tercile
anom_terciles.data[:]

# %% [markdown]
# Box plots

# %%
atemp_upperT = temp_itcz.mean(['lat', 'lon']).where(anomUpperT==1)
atemp_lowerT = temp_itcz.mean(['lat', 'lon']).where(anomLowerT==1) 

data = pd.DataFrame(np.array([net_itcz.time.data, atemp_upperT.data, atemp_lowerT.data], dtype=np.float32).T, columns=['time', 'T upper Tercile', 'T lower Tercile'])
data.boxplot(column=['T upper Tercile', 'T lower Tercile'])
plt.title("High clouds effective T in ITCZ")
plt.ylabel("T (K)")

# %%
lw_itcz = crelw.cre_lw_cldtyp_mon.sel(lat=itcz , lon=ocean, press=[4,5,6,]).sum([ 'opt']).mean(['press', 'lat', 'lon'])
sw_itcz = cresw.cre_sw_cldtyp_mon.sel(lat=itcz , lon=ocean, press=[4,5,6,]).sum([ 'opt']).mean(['press', 'lat', 'lon'])

# %%
lw_upperT = lw_itcz.where(anomUpperT==1)
lw_lowerT = lw_itcz.where(anomLowerT==1) 

data = pd.DataFrame(np.array([net_itcz.time.data, lw_upperT.data, lw_lowerT.data], dtype=np.float32).T, columns=['time', 'lw upper Tercile', 'lw lower Tercile'])
data.boxplot(column=['lw upper Tercile', 'lw lower Tercile'])
plt.title("High clouds mean effective LW in ITCZ")
plt.ylabel("Wm-2 (K)")

# %%
sw_upperT = sw_itcz.where(anomUpperT==1)
sw_lowerT = sw_itcz.where(anomLowerT==1) 

data = pd.DataFrame(np.array([net_itcz.time.data, sw_upperT.data, sw_lowerT.data], dtype=np.float32).T, columns=['time', 'sw upper Tercile', 'sw lower Tercile'])
data.boxplot(column=['sw upper Tercile', 'sw lower Tercile'])
plt.title("High clouds mean effective SW in ITCZ")
plt.ylabel("Wm-2 (K)")

# %%
atau_upperT = odweight.sel(lat=itcz, lon=ocean ).mean([ 'lat', 'lon']).where(anomUpperT==1)
atau_lowerT = odweight.sel(lat=itcz, lon=ocean ).mean(['lat', 'lon']).where(anomLowerT==1)

data = pd.DataFrame(np.array([net_itcz.time.data, atau_upperT.data, atau_lowerT.data], dtype=np.float32).T, columns=['time', 'OD in higher netCRE events', 'OD in lower netCRE events'])
data.boxplot(column=['OD in higher netCRE events', 'OD in lower netCRE events'])
#plt.title("High clouds optical depth")
plt.ylabel("Optical Depth")
plt.ylim(4,15.5)
#plt.savefig("od.svg")

# %%
elnino_od = odweight.sel(lat=newlat,lon=ocean, time=slice('2015-06-15T00:00:00.000000000', '2016-06-15T00:00:00.000000000')).mean([ 'lat', 'lon'])
lanina_od = odweight.sel(lat=newlat,lon=ocean, time=slice('2010-06-15T00:00:00.000000000', '2011-06-15T00:00:00.000000000')).mean([ 'lat', 'lon'])

# %%
enso = pd.DataFrame(np.array([elnino_od.data, lanina_od.data], dtype=np.float32).T, columns=['El nino 15-16', 'La nina 10-11'])
enso.boxplot(column=['El nino 15-16', 'La nina 10-11'])
#plt.title("High clouds optical depth")
plt.ylabel("Optical Depth")
plt.ylim(4,15.5)

# %%
weights = iwp_all.cldarea_cldtyp_mon.sel(lat=newlat, lon=ocean, press=[4,5,6])

# %%
iwp_weig = iwp_all.iwp_cldtyp_mon.sel(lat=newlat, lon=ocean, press=[4,5,6]).weighted(weights).mean(['lat','lon', 'press', 'opt'])

# %%
iwp_clim = iwp_weig.groupby('time.month').mean('time')
iwp_anom = iwp_weig.groupby('time.month') - iwp_clim
iwp_anom.plot()

# %%
iwp_upperT = iwp_weig.where(anomUpperT==1)
iwp_lowerT = iwp_weig.where(anomLowerT==1)

data = pd.DataFrame(np.array([net_itcz.time.data, iwp_upperT.data, iwp_lowerT.data], dtype=np.float32).T, columns=['time', 'IWP in higher netCRE events', 'IWP in lower netCRE events'])
data.boxplot(column=['IWP in higher netCRE events', 'IWP in lower netCRE events'])
plt.title("High clouds IWP weighted by cloud fraction")
plt.ylabel("IWP (g m-2)")

# %%
aarea_upperT = area_itcz.mean(['lat', 'lon']).where(anomUpperT==1)
aarea_lowerT = area_itcz.mean(['lat', 'lon']).where(anomLowerT==1)

data = pd.DataFrame(np.array([net_itcz.time.data, aarea_upperT.data, aarea_lowerT.data], dtype=np.float32).T, columns=['time', 'area upper Tercile', 'area lower Tercile'])
data.boxplot(column=['area upper Tercile', 'area lower Tercile'])
plt.title("High clouds area in ITCZ")
plt.ylabel("Area (%)")

# %%
awpcre_upperT = cre_times.sel( lat=itcz , lon=wp, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).where(anomUpperT==1)
awpcre_lowerT = cre_times.sel( lat=itcz , lon=wp, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).where(anomLowerT==1)

data = pd.DataFrame(np.array([net_itcz.time.data, awpcre_upperT.data, awpcre_lowerT.data], dtype=np.float32).T, columns=['time', 'WP CRE upper Tercile', 'WP CRE lower Tercile'])
data.boxplot(column=['WP CRE upper Tercile', 'WP CRE lower Tercile'])
plt.title("High clouds net CRE in WP")
plt.ylabel("net CRE (Wm-2)")
#plt.ylim([-15,11])

# %%
aepcre_upperT = cre_times.sel( lat=itcz , lon=ep, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).where(anomUpperT==1)
aepcre_lowerT = cre_times.sel( lat=itcz , lon=ep, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).where(anomLowerT==1)

data = pd.DataFrame(np.array([net_itcz.time.data, aepcre_upperT.data, aepcre_lowerT.data], dtype=np.float32).T, columns=['time', 'EP CRE upper Tercile', 'EP CRE lower Tercile'])
data.boxplot(column=['EP CRE upper Tercile', 'EP CRE lower Tercile'])
plt.title("High clouds net CRE in EP")
plt.ylabel("net CRE (Wm-2)")
plt.ylim([-15,11])

# %%
asst_upperT = sst_itcz.where(anomUpperT.data==1)
asst_lowerT = sst_itcz.where(anomLowerT.data==1)

data = pd.DataFrame(np.array([net_itcz.time.data, asst_upperT.data, asst_lowerT.data], dtype=np.float32).T, columns=['time', 'sst upper Tercile', 'sst lower Tercile'])
data.boxplot(column=['sst upper Tercile', 'sst lower Tercile'])
plt.title("SST in ITCZ")
plt.ylabel("Temperature (C)")

# %%
sst_anom_upperT = sst_anom.where(anomUpperT.data==1)
sst_anom_lowerT = sst_anom.where(anomLowerT.data==1)
data = pd.DataFrame(np.array([net_itcz.time.data, sst_anom_upperT.data, sst_anom_lowerT.data], dtype=np.float32).T, columns=['time', 'sst upper Tercile', 'sst lower Tercile'])
data.boxplot(column=['sst upper Tercile', 'sst lower Tercile'])
plt.title("SST anomaly in ITCZ")
plt.ylabel("Temperature (C)")

# %% [markdown]
# ## Tropics

# %%
#cre times is tropics
net_tropics_anom = cre_times.sel(press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']) - cre_times.sel(press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).mean("time") 
net_tropics_terciles = net_tropics_anom.quantile(q=[0.33,0.66], dim="time")
tropicsUpperT = xa.where(cre_times.sel(press=[4,5,6,] ).sum(['press', 'opt']) > net_tropics_terciles[1], 1, np.nan) # upper tercile
tropicsLowerT = xa.where(cre_times.sel(press=[4,5,6,] ).sum(['press', 'opt']) < net_tropics_terciles[0], 1, np.nan) # lower tercile

# %%
sst_latlon = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'), lat=slice(30.5,-30.5), lon=ocean)
new_time = pd.date_range(start='2002-08-01', end='2023-02-01', freq='MS') + pd.DateOffset(days=14)

sst_latlon['time'] = new_time
sst_latlon['time'] = new_time

# %%
sst_anom_latlon = sst_latlon.groupby("time.month") - sst_latlon.groupby("time.month").mean("time")

# %%
# Apply the mask using where
masked_datasetUp = sst_anom_latlon.where(anomUpperT==1., drop=False)
masked_datasetLow = sst_anom_latlon.where(anomLowerT==1., drop=False)

# %%
diff = masked_datasetUp.mean('time') - masked_datasetLow.mean('time')

# %%
#.plot()
plt.figure(figsize=(10,10))
ax1 = plt.axes(projection=usemap_proj)

plot = sst_anom_latlon.where(anomLowerT==1).mean("time").plot(extend='both',transform = ccrs.PlateCarree(), add_colorbar=False)#, extend='both',transform=cart.crs.PlateCarree())

ax1.coastlines(resolution='50m') #transparent
#ax1.set_extent([data.lon.min().data.item(), data.lon.max().data.item(), data.lat.min().data.item(), data.lat.max().data.item()])
gl = ax1.gridlines(draw_labels=True, linewidth=0.5, alpha=0.4, color='k', linestyle='--')
plt.colorbar(plot,fraction=0.019, pad=0.04, label="T ($^\circ C$)")
plt.title('SST anommaly during lower net CRE months')
plt.show()

# %%
plt.figure(figsize=(10,10))
ax1 = plt.axes(projection=usemap_proj)

plot = diff.plot(extend='both',transform = ccrs.PlateCarree(), add_colorbar=False)#, extend='both',transform=cart.crs.PlateCarree())

ax1.coastlines(resolution='50m') #transparent
#ax1.set_extent([data.lon.min().data.item(), data.lon.max().data.item(), data.lat.min().data.item(), data.lat.max().data.item()])
gl = ax1.gridlines(draw_labels=True, linewidth=0.5, alpha=0.4, color='k', linestyle='--')
ax1.add_patch(patches.Rectangle(xy=[120, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[160, 0], width=40, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[210, 0], width=50, height=20, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
plt.colorbar(plot, fraction=0.019, pad=0.04, label="T ($^\circ C$)")
plt.title('SST anommaly difference: upper tercile - lower tercile')
plt.show()

# %% [markdown]
# # Terciles maps composites

# %%
# Expand dimensions of mask to match dataset
expanded_maskUp = anomUpperT.expand_dims(dim={"lat":sst_latlon['lat'], "lon":sst_latlon['lon']}, axis=(1,2))
expanded_maskLow = anomLowerT.expand_dims(dim={"lat":sst_latlon['lat'], "lon":sst_latlon['lon']}, axis=(1,2))
expanded_maskUp

# %% [markdown]
# ## Thin clouds area

# %%
thin_area

# %%
expanded_maskLow.sel(lat=slice(20.5, -0.5), lon=ocean)

# %%
# THIN High clouds area in ITCZ
thin_area = alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=ocean, press=[4,5,6], opt=[0,1]).sum(["press", "opt"])
# le cambie las coordenadas a la mascara
thin_area_upperT = thin_area.where(expanded_maskUp.sel(lat=slice(20.5, -0.5), lon=ocean) == 1., drop=False)
thin_area_lowerT = thin_area.where(expanded_maskLow.sel(lat=slice(20.5, -0.5), lon=ocean) == 1., drop=False)

diff = thin_area_upperT.mean('time') - thin_area_lowerT.mean('time')
diff.plot()

# %%
thin_area_upperT

# %% [markdown]
# ## Thick clouds area

# %%
# THIN High clouds area in ITCZ
thick_area = alltau.cldarea_cldtyp_mon.sel(lat=trop, press=[4,5,6], opt=[4,5]).sum(["press", "opt"])
# le cambie las coordenadas a la mascara
thick_area_upperT = thick_area.where(anomUpperT == 1., drop=False)
thick_area_lowerT = thick_area.where(anomLowerT == 1., drop=False)

diff = thick_area_upperT.mean('time') - thick_area_lowerT.mean('time')

# %%
diff.plot()

# %% [markdown]
# ## SSTs

# %%
sst_latlon = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'), lat=slice(30.5,-30.5), lon=slice(110.5,269.5))

# %%
#Define new time: ONly for SSTs
new_time = pd.date_range(start='2002-08-01', end='2023-02-01', freq='MS')

anomUpperT['time'] = new_time
anomLowerT['time'] = new_time

# %%
sst_anom_latlon = sst_latlon.groupby("time.month") - sst_latlon.groupby("time.month").mean("time")

# %%
# Apply the mask using where
masked_datasetUp = sst_anom_latlon.where(expanded_maskUp == 1., drop=False)
masked_datasetUp

# %%
# Apply the mask using where
masked_datasetLow = sst_anom_latlon.where(expanded_maskLow == 1., drop=False)

# %%
diff = masked_datasetUp.mean('time') - masked_datasetLow.mean('time')

# %%
diff

# %%
masked_datasetUp.mean('time').plot()

# %%
plt.figure(figsize=(10,10))
ax1 = plt.axes(projection=usemap_proj)

plot = diff.plot(extend='both',transform = ccrs.PlateCarree(), add_colorbar=False)#, extend='both',transform=cart.crs.PlateCarree())

ax1.coastlines(resolution='50m') #transparent
#ax1.set_extent([data.lon.min().data.item(), data.lon.max().data.item(), data.lat.min().data.item(), data.lat.max().data.item()])
gl = ax1.gridlines(draw_labels=True, linewidth=0.5, alpha=0.4, color='k', linestyle='--')
ax1.add_patch(patches.Rectangle(xy=[120, 5], width=40, height=10, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[160, 5], width=40, height=10, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
ax1.add_patch(patches.Rectangle(xy=[210, 5], width=50, height=10, facecolor='none', edgecolor='k', transform=ccrs.PlateCarree()))
plt.colorbar(plot,fraction=0.019, pad=0.04)
plt.title('SST anommaly difference upper tercile - lower tercile')
plt.show()

# %%
#Seasonal anomalies
climatology_itcz = sst_itcz.groupby("time.season").mean("time")
climatology_mean_itcz = sst_itcz.groupby("time.season").mean("time")
anomalies = sst_itcz.groupby("time.season") - climatology_mean_itcz
plt.figure(figsize=(15,9))

anomalies.plot() 
plt.title("SST anomalies")
plt.ylabel("Temperature (C)")
plt.grid(visible=True, axis='x')

# Convert integer months to actual dates
#date_labels = [date.strftime('%Y-%d-%m') for date in dates]
#tick_locations = np.arange(0, len(anomalies.time.data), 6)  # Show ticks every 12 months
#plt.xticks(tick_locations, date_labels[::6], rotation=45)
plt.savefig("sst_timesseries.png")

# %% [markdown]
# # 10th/ 90th Percentiles

# %%
p90 = net_anom.quantile(q=[0.1,0.9], dim="time")
anomUpperT = xa.where(net_anom > p90[1], 1, np.nan) # upper tercile
anomLowerT = xa.where(net_anom < p90[0], 1, np.nan)  # lower tercile
p90.data[:]

# %% [markdown]
# # Thin vs thick clouds

# %%
# THIN High clouds area in ITCZ
thin_area = alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=ocean, press=[4,5,6], opt=[0,1]).mean(['lat', 'lon']).sum(["press", "opt"])
thin_area_upperT = thin_area.where(anomUpperT==1)
thin_area_lowerT = thin_area.where(anomLowerT==1)

# %%
data = pd.DataFrame(np.array([thin_area.time.data, thin_area_upperT.data, thin_area_lowerT.data], dtype=np.float32).T, columns=['time', 'thin clouds area in upper tercile', 'thin clouds area in lower tercile'])
data.boxplot(column=['thin clouds area in upper tercile', 'thin clouds area in lower tercile'])
plt.title("Thin high clouds area in ITCZ")
plt.ylabel("Clouds Area")

# %%
thick_area = alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=ocean, press=[4,5,6], opt=[4,5]).mean(['lat', 'lon']).sum(["press", "opt"])

thick_area_upperT = thick_area.where(anomUpperT==1)
thick_area_lowerT = thick_area.where(anomLowerT==1)

# %%
data = pd.DataFrame(np.array([net_itcz.time.data, thick_area_upperT.data, thick_area_lowerT.data], dtype=np.float32).T, columns=['time', 'thick clouds area in upper tercile', 'thick clouds area in lower tercile'])
data.boxplot(column=['thick clouds area in upper tercile', 'thick clouds area in lower tercile'])
plt.title("Thick high clouds area in ITCZ")
plt.ylabel("Clouds Area")

# %% [markdown]
# Ratios

# %%
ratioUp = thick_area_upperT/thin_area_upperT
ratioLow = thick_area_lowerT/thin_area_lowerT

# %%
data = pd.DataFrame(np.array([net_itcz.time.data, ratioUp.data, ratioLow.data], dtype=np.float32).T, columns=['time', 'ratio in upper netCRE tercile', 'ratio in lower netCRE tercile'])
data.boxplot(column=['ratio in upper netCRE tercile', 'ratio in lower netCRE tercile'])
#plt.title("ratio high clouds area in ITCZ")
plt.ylabel("ratio thin cf/thick cf")
plt.savefig("rationthnthik.png")

# %%
ratio = thick_area/thin_area
ratio_area_upperT = ratio.where(anomUpperT==1)
ratio_area_lowerT = ratio.where(anomLowerT==1)

data = pd.DataFrame(np.array([net_itcz.time.data, ratio_area_upperT.data, ratio_area_lowerT.data], dtype=np.float32).T, columns=['time', 'ratio upper tercile', 'ratio lower tercile'])
bp = data.boxplot(column=['ratio upper tercile', 'ratio lower tercile'])
plt.title("thick/thin high clouds area in ITCZ")
plt.ylabel("Clouds Area")

# %%
thick_area_anom = thick_area.groupby("time.month") - thick_area.groupby("time.month").mean("time")
thin_area_anom = thin_area.groupby("time.month") - thin_area.groupby("time.month").mean("time")

thick_area_anom.plot(color='b', label = "thick") #thick=blue
thin_area_anom.plot(color='r', label = "thin") #thin=red
plt.legend(loc="upper right")
plt.ylabel("Cloud fraction anomaly (%)")
plt.savefig("thn-thck_timesseries.png")

# %%
cor = xa.corr(thick_area_anom, thin_area_anom, dim="time")
cor

# %%
def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers

# %%
thick_area_wp = alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=wp, press=[4,5,6], opt=[4,5]).mean(['lat', 'lon']).sum(["press", "opt"])
thick_area_ep = alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=ep, press=[4,5,6], opt=[4,5]).mean(['lat', 'lon']).sum(["press", "opt"])

thin_area_wp = alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=wp, press=[4,5,6], opt=[0,1]).mean(['lat', 'lon']).sum(["press", "opt"])
thin_area_ep = alltau.cldarea_cldtyp_mon.sel(lat=newlat, lon=ep, press=[4,5,6], opt=[0,1]).mean(['lat', 'lon']).sum(["press", "opt"])

# %%
# Monthly climatology high clouds net CRE times area in ITCZ
fig, ((ax1, ax2), (ax3, ax4))  = plt.subplots(2,2, figsize=(10,8))

thin_area_wp.groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax1) 
ax1.set_ylabel("Thin cloud fraction (%)")
ax1.grid(visible=True, axis='both')
ax1.set_xticks(np.arange(1,13,1))
ax1.set_xticklabels(months)
ax1.set_title("a) WP", loc="left")

thin_area_ep.groupby("time.month").mean("time").plot(linewidth=0.6,  ax=ax2) 
ax2.set_ylabel("")
ax2.grid(visible=True, axis='both')
ax2.set_xticks(np.arange(1,13,1))
ax2.set_xticklabels(months)
ax2.set_title("b) EP", loc="left")

thick_area_wp.groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax3) 
ax3.grid(visible=True, axis='both')
ax3.set_ylabel("Thick cloud fraction (%)")
ax3.set_xticks(np.arange(1,13,1))
ax3.set_xticklabels(months)
ax3.set_title("", loc="left")


thick_area_ep.groupby("time.month").mean("time").plot(linewidth=0.6, ax=ax4) 
ax4.set_ylabel("")
ax4.grid(visible=True, axis='both')
ax4.set_xticks(np.arange(1,13,1))
ax4.set_xticklabels(months)
ax4.set_title("", loc="left")

plt.savefig("pictures/thn-tck-clims.png")

# %% [markdown]
# # Time series

# %%
#Whole domain Net CRE
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'

p1, = cre_times.sel( lat=itcz , press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(120.5,289.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("netCRE 12-mon rolling mean - Lat=[5,15], Lon=[120,280], p<440hPa")
ax1.set_ylabel("Net CRE (Wm-2)")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#WP Net CRE
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_ylabel("Net CRE (Wm-2)")
p1, = cre_times.sel( lat=itcz , lon=wp, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(120.5,160.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("WP netCRE 12-mon rolling mean - Lat=[5,15], p<440hPa")
ax1.set_ylabel("Net CRE (Wm-2)")

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
#EP
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_ylabel("Net CRE (Wm-2)")
p1, = cre_times.sel( lat=itcz , lon=ep, press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(210.5,260.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("EP netCRE 12-mon rolling mean - Lat=[5,15], p<440hPa")
ax1.set_ylabel("Net CRE (Wm-2)")

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
#Whole domain Optical depth

tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'

p1, = odweight.mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(120.5,289.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Mon rolling mean - Lat=[5,15], Lon=[120,280], p<440hPa")
ax1.set_ylabel("Optical Depth")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#WP OD
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
p1, = odtropics.sel(lon=wp).weighted(area_tropics.sel(lon=wp)).mean(['press', 'opt','lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(120.5,160.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("WP High clouds - Mon rolling mean")
ax1.set_ylabel("Optical Depth")
#fig.tight_layout()  # otherwise the right y-label is slightly clipped


ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#EP
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
p1, = odtropics.sel(lon=ep).weighted(area_tropics.sel(lon=ep)).mean(['press', 'opt','lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(210.5,260.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Optical Depth EP High clouds - Mon rolling mean")
ax1.set_ylabel("Optical Depth")
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#Whole domain area

tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
area = alltau.cldarea_cldtyp_mon.sel(lat=itcz, press=[6,5,4])

p1, = area.sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(120.5,289.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Mon rolling mean - Lat=[5,15], Lon=[120,280], p<440hPa")
ax1.set_ylabel("Cloud area %")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#Whole domain area

tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'

p1, = area.sel(lat=itcz).sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(120.5,289.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Mon rolling mean - Lat=[5,15], Lon=[120,280], p<440hPa")
ax1.set_ylabel("Cloud area % mean")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#WP area

tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
area = alltau.cldarea_cldtyp_mon.sel(lat=itcz, lon=wp, press=[6,5,4])

p1, = area.sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(120.5,160.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Mon rolling mean - Lat=[5,15], Lon=WP, p<440hPa")
ax1.set_ylabel("Cloud area %")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#ep area

tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
area = alltau.cldarea_cldtyp_mon.sel(lat=itcz, lon=ep, press=[6,5,4])

p1, = area.sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'),
            lat=slice(15.5,5.5), lon=slice(210.5,260.5) ).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Mon rolling mean - Lat=[5,15], Lon=EP, p<440hPa")
ax1.set_ylabel("Cloud area %")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %% [markdown]
# # Quintiles

# %%
quintiles = net_anom.quantile(q=[0.2, 0.4, 0.6, 0.8], dim="time")
quintiles.data[:]

# %%
# Monthly climatology High clouds net CRE times area in ITCZ
fig, ax1 = plt.subplots(figsize=(10,6))
net_month_clim = cre_times.sel( lat=itcz , press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).groupby("time.month").mean("time")
net_anom = cre_times.sel( lat=itcz , press=[4,5,6,] ).sum(['press', 'opt']).mean(['lat', 'lon']).groupby("time.month") - net_month_clim
plt.plot(net_anom)
plt.title("High clouds netCRE x cloud area monthly anomaly in ITCZ")
plt.xlim(-1,248)
plt.ylabel("net CRE (Wm-2)")
plt.axhline(y=quintiles[0], color='r', linestyle='-')
plt.axhline(y=quintiles[-1], color='r', linestyle='-')
ax1.grid(visible=True, axis='x')
# Convert integer months to actual dates
start_date = pd.to_datetime('2002-08-01')
dates = pd.date_range(start_date, periods=len(net_anom.time.data), freq='M')
date_labels = [date.strftime('%Y-%m') for date in dates]
tick_locations = np.arange(0, len(net_anom.time.data), 12)  # Show ticks every 12 months
plt.xticks(tick_locations, date_labels[::12], rotation=45)

# %% [markdown]
# # Anomalies vs SSTs
#
# Climatology: group monthly anomaly
#
# First, trim the period, latitudes and longitudes of interest, and mean across all lats and longs
#
# The ONI is the rolling 3-month average temperature anomaly—difference from average—in the surface waters of the east-central tropical Pacific, near the International Dateline.

# %%
#Whole domain area

tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'

p1, = area.sel(lat=itcz).sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=3, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = stand_anomalies.plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)
ax2.set_ylabel("SST std anom (C)")

plt.suptitle("Std anom - Lat=[5,15], Lon=[120,280], p<440hPa")
ax1.set_ylabel("Cloud area % mean")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
# WP anomalies

#SSTs monthly anomalies
sst_wp = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'), 
                       lat=slice(15.5,5.5), lon=wp ).mean(['lat', 'lon'])
climatology_mean = sst_wp.groupby("time.month").mean("time")
wp_anomalies = sst_wp.groupby("time.month") - climatology_mean


tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
area = alltau.cldarea_cldtyp_mon.sel(lat=itcz, lon=wp, press=[6,5,4])

p1, = area.sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = wp_anomalies.plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Mon rolling mean - Lat=[5,15], Lon=WP, p<440hPa")
ax1.set_ylabel("Cloud area %")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#ep area anomalies

#SSTs monthly anomalies
sst_ep = sst.sst.sel(time=slice('2002-08-01T00:00:00.000000000','2023-02-01T00:00:00.000000000'), 
                       lat=slice(15.5,5.5), lon=ep ).mean(['lat', 'lon'])

climatology_mean = sst_ep.groupby("time.month").mean("time")
ep_anomalies = sst_ep.groupby("time.month") - climatology_mean


tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
area = alltau.cldarea_cldtyp_mon.sel(lat=itcz, lon=ep, press=[6,5,4])

p1, = area.sum(['press', 'opt']).mean(['lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = ep_anomalies.plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Mon rolling mean - Lat=[5,15], Lon=EP, p<440hPa")
ax1.set_ylabel("Cloud area %")
fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#WP OD
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
p1, = odtropics.sel(lon=wp).weighted(area_tropics.sel(lon=wp)).mean(['press', 'opt','lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = wp_anomalies.plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Optical depth WP high clouds - Month anom")
ax1.set_ylabel("Optical Depth")
#fig.tight_layout()  # otherwise the right y-label is slightly clipped


ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#EP
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
p1, = odtropics.sel(lon=ep).weighted(area_tropics.sel(lon=ep)).mean(['press', 'opt','lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = ep_anomalies.plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Optical depth EP high clouds - Month anom")
ax1.set_ylabel("Optical Depth")
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()

# %%
#EP
tkw = dict(size=4, width=1.5)
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_ylabel("Net CRE (Wm-2)")
p1, = odtropics.sel(lon=wp).weighted(area_tropics.sel(lon=wp)).mean(['press', 'opt','lat', 'lon']).rolling(time=12, center=True).mean().plot(linewidth=0.6, ax=ax1, color=color) 
ax1.tick_params(axis='y', labelcolor=color, **tkw)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
p2, = wp_anomalies.plot(linewidth=0.6, ax=ax2, color=color)#ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color, **tkw)

plt.suptitle("Optical depth EP high clouds - Month anom")
ax1.set_ylabel("Optical Depth")
#fig.tight_layout()  # otherwise the right y-label is slightly clipped

ax1.xaxis.set_major_locator(mdates.YearLocator(base=2)) 
ax1.grid(visible=True, axis='x')
plt.show()
